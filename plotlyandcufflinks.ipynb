# %%
# !pip install plotly
# !pip install cufflinks
# Out:
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: plotly in c:\python312\lib\site-packages (6.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in c:\python312\lib\site-packages (from plotly) (2.6.0)
# Requirement already satisfied: packaging in c:\python312\lib\site-packages (from plotly) (25.0)
# Collecting cufflinks
#   Downloading cufflinks-0.17.3.tar.gz (81 kB)
#      ---------------------------------------- 0.0/81.7 kB ? eta -:--:--
#      ----- ---------------------------------- 10.2/81.7 kB ? eta -:--:--
#      ----------------------- -------------- 51.2/81.7 kB 525.1 kB/s eta 0:00:01
#      --------------------------------- ---- 71.7/81.7 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 81.7/81.7 kB 507.1 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting numpy>=1.9.2 (from cufflinks)
#   Downloading numpy-2.3.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      --------------------------------- ------ 51.2/60.9 kB ? eta -:--:--
#      -------------------------------------- 60.9/60.9 kB 804.7 kB/s eta 0:00:00
# Collecting pandas>=0.19.2 (from cufflinks)
#   Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: plotly>=4.1.1 in c:\python312\lib\site-packages (from cufflinks) (6.3.1)
# Collecting six>=1.9.0 (from cufflinks)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting colorlover>=0.2.1 (from cufflinks)
#   Downloading colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Collecting setuptools>=34.4.1 (from cufflinks)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting ipython>=5.3.0 (from cufflinks)
#   Downloading ipython-9.6.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting ipywidgets>=7.0.0 (from cufflinks)
#   Downloading ipywidgets-8.1.7-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: colorama in c:\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (0.4.6)
# Collecting decorator (from ipython>=5.3.0->cufflinks)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting ipython-pygments-lexers (from ipython>=5.3.0->cufflinks)
#   Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting jedi>=0.16 (from ipython>=5.3.0->cufflinks)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython>=5.3.0->cufflinks)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython>=5.3.0->cufflinks)
#   Downloading prompt_toolkit-3.0.52-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pygments>=2.4.0 in c:\python312\lib\site-packages (from ipython>=5.3.0->cufflinks) (2.18.0)
# Collecting stack_data (from ipython>=5.3.0->cufflinks)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython>=5.3.0->cufflinks)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting comm>=0.1.3 (from ipywidgets>=7.0.0->cufflinks)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets>=7.0.0->cufflinks)
#   Downloading widgetsnbextension-4.0.14-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets>=7.0.0->cufflinks)
#   Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl.metadata (20 kB)
# Collecting python-dateutil>=2.8.2 (from pandas>=0.19.2->cufflinks)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=0.19.2->cufflinks)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=0.19.2->cufflinks)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: narwhals>=1.15.1 in c:\python312\lib\site-packages (from plotly>=4.1.1->cufflinks) (2.6.0)
# Requirement already satisfied: packaging in c:\python312\lib\site-packages (from plotly>=4.1.1->cufflinks) (25.0)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython>=5.3.0->cufflinks)
#   Downloading parso-0.8.5-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.3.0->cufflinks)
#   Downloading wcwidth-0.2.14-py2.py3-none-any.whl.metadata (15 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython>=5.3.0->cufflinks)
#   Downloading executing-2.2.1-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython>=5.3.0->cufflinks)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython>=5.3.0->cufflinks)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# Downloading ipython-9.6.0-py3-none-any.whl (616 kB)
#    ---------------------------------------- 0.0/616.2 kB ? eta -:--:--
#    --------------------------------- ----- 522.2/616.2 kB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 616.2/616.2 kB 7.8 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.7-py3-none-any.whl (139 kB)
#    ---------------------------------------- 0.0/139.8 kB ? eta -:--:--
#    ---------------------------------------- 139.8/139.8 kB 4.2 MB/s eta 0:00:00
# Downloading numpy-2.3.3-cp312-cp312-win_amd64.whl (12.8 MB)
#    ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#    - -------------------------------------- 0.4/12.8 MB 7.4 MB/s eta 0:00:02
#    --- ------------------------------------ 1.2/12.8 MB 12.2 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.7/12.8 MB 12.2 MB/s eta 0:00:01
#    ------- -------------------------------- 2.3/12.8 MB 12.1 MB/s eta 0:00:01
#    -------- ------------------------------- 2.8/12.8 MB 12.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.4/12.8 MB 12.0 MB/s eta 0:00:01
#    ------------ --------------------------- 3.9/12.8 MB 11.9 MB/s eta 0:00:01
#    -------------- ------------------------- 4.5/12.8 MB 11.9 MB/s eta 0:00:01
#    --------------- ------------------------ 5.0/12.8 MB 11.9 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.3/12.8 MB 11.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.8 MB 10.9 MB/s eta 0:00:01
#    ------------------ --------------------- 6.0/12.8 MB 10.7 MB/s eta 0:00:01
#    -------------------- ------------------- 6.5/12.8 MB 10.7 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.8 MB 10.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 7.5/12.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.8 MB 10.7 MB/s eta 0:00:01
#    -------------------------- ------------- 8.5/12.8 MB 10.6 MB/s eta 0:00:01
#    --------------------------- ------------ 8.8/12.8 MB 10.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.5/12.8 MB 10.7 MB/s eta 0:00:01
#    ------------------------------- -------- 10.1/12.8 MB 10.7 MB/s eta 0:00:01
#    --------------------------------- ------ 10.6/12.8 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.2/12.8 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.7/12.8 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 12.2/12.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  12.7/12.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.8 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 12.8/12.8 MB 9.8 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -- ------------------------------------- 0.6/11.0 MB 13.3 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.2/11.0 MB 12.5 MB/s eta 0:00:01
#    ------ --------------------------------- 1.7/11.0 MB 12.3 MB/s eta 0:00:01
#    -------- ------------------------------- 2.3/11.0 MB 12.1 MB/s eta 0:00:01
#    ---------- ----------------------------- 2.8/11.0 MB 11.8 MB/s eta 0:00:01
#    ------------ --------------------------- 3.3/11.0 MB 11.7 MB/s eta 0:00:01
#    -------------- ------------------------- 3.9/11.0 MB 12.3 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.4/11.0 MB 12.2 MB/s eta 0:00:01
#    ------------------ --------------------- 5.0/11.0 MB 12.2 MB/s eta 0:00:01
#    ------------------- -------------------- 5.5/11.0 MB 12.1 MB/s eta 0:00:01
#    --------------------- ------------------ 6.0/11.0 MB 12.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.0 MB 12.0 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 12.0 MB/s eta 0:00:01
#    --------------------------- ------------ 7.7/11.0 MB 11.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.2/11.0 MB 11.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 9.3/11.0 MB 11.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.0 MB 11.8 MB/s eta 0:00:01
#    ------------------------------------- -- 10.4/11.0 MB 11.7 MB/s eta 0:00:01
#    ---------------------------------------  10.8/11.0 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 11.3 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.9 MB/s eta 0:00:00
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ---------------- ----------------------- 0.7/1.6 MB 13.9 MB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.6 MB 12.9 MB/s eta 0:00:01
#    ---------------------------------------  1.6/1.6 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 9.1 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.15-py3-none-any.whl (216 kB)
#    ---------------------------------------- 0.0/216.6 kB ? eta -:--:--
#    --------------------------------------- 216.6/216.6 kB 12.9 MB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
#    ---------------------------------------- 0.0/391.4 kB ? eta -:--:--
#    ---------------------------------------- 391.4/391.4 kB 8.1 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
#    ---------------------------------------- 0.0/229.9 kB ? eta -:--:--
#    --------------------------------------- 229.9/229.9 kB 13.7 MB/s eta 0:00:00
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
#    ---------------------------------------- 0.0/509.2 kB ? eta -:--:--
#    --------------------------------------  501.8/509.2 kB 10.5 MB/s eta 0:00:01
#    ---------------------------------------- 509.2/509.2 kB 8.0 MB/s eta 0:00:00
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
#    ---------------------------------------- 0.0/85.4 kB ? eta -:--:--
#    ---------------------------------------- 85.4/85.4 kB 5.0 MB/s eta 0:00:00
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
#    ---------------------------------------- 0.0/347.8 kB ? eta -:--:--
#    --------------------------------------- 347.8/347.8 kB 10.5 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.14-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 16.8 MB/s eta 0:00:01
#    -------------------- ------------------- 1.1/2.2 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 1.6/2.2 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------  2.2/2.2 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 8.7 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading ipython_pygments_lexers-1.1.1-py3-none-any.whl (8.1 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Downloading parso-0.8.5-py2.py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.7 kB ? eta -:--:--
#    ---------------------------------------- 106.7/106.7 kB 6.0 MB/s eta 0:00:00
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.2.14-py2.py3-none-any.whl (37 kB)
# Building wheels for collected packages: cufflinks
#   Building wheel for cufflinks (pyproject.toml): started
#   Building wheel for cufflinks (pyproject.toml): finished with status 'done'
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68561 sha256=b18424eac35896a5d1473a83c5fe256da0149d5a155faeed4fb2b83c36313750
#   Stored in directory: c:\users\my pc\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# Installing collected packages: pytz, pure-eval, colorlover, widgetsnbextension, wcwidth, tzdata, traitlets, six, setuptools, parso, numpy, jupyterlab_widgets, ipython-pygments-lexers, executing, decorator, comm, asttokens, stack_data, python-dateutil, prompt_toolkit, matplotlib-inline, jedi, pandas, ipython, ipywidgets, cufflinks
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Python312\\etc'
# Consider using the `--user` option or check the permissions.
#
#
# [notice] A new release of pip is available: 24.0 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns
import pandas as pd 
import cufflinks as cf 
from plotly.offline import iplot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import seaborn as sns
#       2 import pandas as pd
# ----> 3 import cufflinks as cf
#       4 from plotly.offline import iplot
#
# ModuleNotFoundError: No module named 'cufflinks'

# %%
tips = sns.load_dataset('tips')
tips
